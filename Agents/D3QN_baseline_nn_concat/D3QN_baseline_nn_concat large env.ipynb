# %% [markdown]
# # Import

# %%
import grid2op
from grid2op.PlotGrid import PlotMatplot 
from grid2op.utils import ScoreL2RPN2020
from grid2op.Runner import Runner
from grid2op.Reward import *
from grid2op.Action import *
import numpy as np
import pdb
import os
import pickle
import copy
import matplotlib.pyplot as plt

from train import train as train
from evaluate import evaluate as evaluate
from DoubleDuelingDQN import DoubleDuelingDQN as D3QNAgent

# %% [markdown]
# # Training

# %%
env_train = grid2op.make('l2rpn_neurips_2020_track1_large_train',
                         action_class=TopologyChangeAndDispatchAction,                         
                         reward_class=CombinedScaledReward)


# Only load 128 steps in ram
env_train.chronics_handler.set_chunk_size(128)

# %%
train_iter = 150000
agent_name = "DDQN_baseline_nn_concat_large"
save_path = "saved_agent_DDQN_baseline_nn_concat_large_{}".format(train_iter)
logs_dir="tf_logs_DDQN_baseline_nn_concat_large"
batch_size = 32 
num_pre_training_steps = 0
num_frames = 4
learning_rate = 0.00001

# Register custom reward for training
cr = env_train._reward_helper.template_reward
#cr.addReward("overflow", CloseToOverflowReward(), 1.0)
cr.addReward("game", GameplayReward(), 1.0)
#cr.addReward("recolines", LinesReconnectedReward(), 1.0)
cr.addReward("l2rpn", L2RPNReward(), 2.0/float(env_train.n_line))
# Initialize custom rewards
cr.initialize(env_train)
# Set reward range to something managable
cr.set_range(-1.0, 1.0)

env_train.seed(0)

train(env_train,
      name=agent_name,
      iterations=train_iter,
      save_path=save_path,
      load_path=None, 
      logs_path=logs_dir,
      num_frames = num_frames,
      num_pre_training_steps= num_pre_training_steps,
      batch_size=batch_size,
      learning_rate=learning_rate)
# Out:
# Step [0] -- Random [0.99]
# Survived [1] steps
# Total reward [-0.17148780822753906]
# Survived [0] steps
# Total reward [-1.0]
# Survived [4] steps
# Total reward [1.4153572916984558]
# Survived [4] steps
# Total reward [1.6939212083816528]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.1382274627685547]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.6342287063598633]
# Survived [7] steps
# Total reward [3.744697332382202]
# Survived [3] steps
# Total reward [1.5488134622573853]
# Survived [8] steps
# Total reward [4.751070499420166]
# Survived [6] steps
# Total reward [2.9071423411369324]
# Survived [5] steps
# Total reward [2.93871009349823]
# Survived [1] steps
# Total reward [-0.14444994926452637]
# Survived [4] steps
# Total reward [0.8003804683685303]
# Survived [3] steps
# Total reward [1.3317359685897827]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.14603197574615479]
# Survived [1] steps
# Total reward [-0.12535762786865234]
# Survived [3] steps
# Total reward [1.4872857332229614]
# Survived [0] steps
# Total reward [-1.0]
# Survived [8] steps
# Total reward [5.112700343132019]
# Survived [0] steps
# Total reward [-1.0]
# Survived [9] steps
# Total reward [4.989367365837097]
# Survived [3] steps
# Total reward [1.5611729621887207]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [7] steps
# Total reward [3.784264922142029]
# Survived [20] steps
# Total reward [13.366334557533264]
# Survived [11] steps
# Total reward [6.805827498435974]
# Survived [6] steps
# Total reward [3.9919708967208862]
# Survived [1] steps
# Total reward [-0.13489985466003418]
# Survived [2] steps
# Total reward [0.7142325639724731]
# Survived [5] steps
# Total reward [3.0534634590148926]
# Survived [1] steps
# Total reward [-0.1562107801437378]
# loss = 426.4543
# Survived [9] steps
# Total reward [5.165258765220642]
# Survived [0] steps
# Total reward [-1.0]
# Survived [3] steps
# Total reward [0.7784214019775391]
# Survived [7] steps
# Total reward [3.2794345021247864]
# Survived [3] steps
# Total reward [1.5670995712280273]
# Survived [0] steps
# Total reward [-1.0]
# Survived [5] steps
# Total reward [3.2010700702667236]
# Survived [0] steps
# Total reward [-1.0]
# Survived [3] steps
# Total reward [1.5177037715911865]
# Survived [1] steps
# Total reward [-0.12727856636047363]
# Survived [3] steps
# Total reward [0.41601330041885376]
# Survived [3] steps
# Total reward [1.5400662422180176]
# Survived [5] steps
# Total reward [3.102173686027527]
# loss = 160.01758
# Survived [6] steps
# Total reward [3.508830428123474]
# Survived [6] steps
# Total reward [3.76388156414032]
# Survived [6] steps
# Total reward [3.8144633769989014]
# Survived [0] steps
# Total reward [-1.0]
# Survived [4] steps
# Total reward [2.2890223264694214]
# Survived [11] steps
# Total reward [5.876374125480652]
# Survived [1] steps
# Total reward [-0.14937233924865723]
# Survived [3] steps
# Total reward [1.4926769733428955]
# Survived [5] steps
# Total reward [3.165671706199646]
# Survived [2] steps
# Total reward [0.6240744590759277]
# Survived [6] steps
# Total reward [3.248539447784424]
# Survived [0] steps
# Total reward [-1.0]
# loss = 84.33847
# Survived [0] steps
# Total reward [-1.0]
# Survived [4] steps
# Total reward [2.1951048374176025]
# Survived [2] steps
# Total reward [0.7251505851745605]
# Survived [3] steps
# Total reward [1.3860666751861572]
# Survived [3] steps
# Total reward [1.596126675605774]
# Survived [11] steps
# Total reward [7.205350339412689]
# Survived [6] steps
# Total reward [3.6208654642105103]
# Survived [2] steps
# Total reward [0.6863322257995605]
# Survived [3] steps
# Total reward [1.5281620025634766]
# Survived [2] steps
# Total reward [0.6926532983779907]
# Survived [8] steps
# Total reward [3.4531770944595337]
# loss = 111.17249
# Survived [4] steps
# Total reward [1.622061312198639]
# Survived [2] steps
# Total reward [0.7175410985946655]
# Survived [1] steps
# Total reward [-0.1564086675643921]
# Survived [6] steps
# Total reward [3.7359719276428223]
# Survived [2] steps
# Total reward [-0.014393508434295654]
# Survived [8] steps
# Total reward [4.57583349943161]
# Survived [1] steps
# Total reward [-0.15764260292053223]
# Survived [1] steps
# Total reward [-0.1558542251586914]
# Survived [5] steps
# Total reward [3.2414774894714355]
# Survived [0] steps
# Total reward [-1.0]
# Survived [7] steps
# Total reward [4.633907794952393]
# Survived [1] steps
# Total reward [-0.1478186845779419]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.1527196168899536]
# Survived [2] steps
# Total reward [0.729958176612854]
# loss = 240.18027
# Survived [4] steps
# Total reward [2.3215322494506836]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.1578439474105835]
# Survived [7] steps
# Total reward [4.757046580314636]
# Survived [1] steps
# Total reward [-0.1388413906097412]
# Survived [3] steps
# Total reward [0.5734239220619202]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.5821067094802856]
# Survived [6] steps
# Total reward [3.3398267030715942]
# Survived [1] steps
# Total reward [-0.15750133991241455]
# Survived [0] steps
# Total reward [-1.0]
# Survived [5] steps
# Total reward [3.200857996940613]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [4] steps
# Total reward [2.3843116760253906]
# loss = 120.033104
# Survived [10] steps
# Total reward [5.386488735675812]
# Survived [1] steps
# Total reward [-0.1615356206893921]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.5238960981369019]
# Survived [0] steps
# Total reward [-1.0]
# Survived [3] steps
# Total reward [1.0605230331420898]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.1750011444091797]
# Survived [3] steps
# Total reward [1.5229952335357666]
# Survived [5] steps
# Total reward [3.12773597240448]
# Survived [6] steps
# Total reward [3.3987794518470764]
# Survived [5] steps
# Total reward [3.2856059074401855]
# Survived [9] steps
# Total reward [4.55112236738205]
# Survived [0] steps
# Total reward [-1.0]
# loss = 105.892746
# Survived [11] steps
# Total reward [8.0646390914917]
# Survived [3] steps
# Total reward [0.5984480381011963]
# Survived [3] steps
# Total reward [0.814242959022522]
# Survived [5] steps
# Total reward [2.9108197689056396]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.17852473258972168]
# Survived [5] steps
# Total reward [2.398275136947632]
# Survived [4] steps
# Total reward [2.296995162963867]
# Survived [1] steps
# Total reward [-0.14366626739501953]
# loss = 26.184128
# Survived [22] steps
# Total reward [13.546644032001495]
# Survived [0] steps
# Total reward [-1.0]
# Survived [13] steps
# Total reward [6.164092838764191]
# Survived [1] steps
# Total reward [-0.14817523956298828]
# Survived [0] steps
# Total reward [-1.0]
# Survived [13] steps
# Total reward [8.458140134811401]
# Survived [3] steps
# Total reward [1.5570350885391235]
# Survived [2] steps
# Total reward [0.6931753158569336]
# Survived [1] steps
# Total reward [-0.1414731740951538]
# Survived [5] steps
# Total reward [2.549139440059662]
# loss = 57.444298
# Survived [16] steps
# Total reward [9.528187692165375]
# Survived [8] steps
# Total reward [5.723848581314087]
# Survived [2] steps
# Total reward [0.6591707468032837]
# Survived [3] steps
# Total reward [0.9553953409194946]
# Survived [6] steps
# Total reward [2.663432776927948]
# Survived [10] steps
# Total reward [6.8690080642700195]
# Survived [5] steps
# Total reward [2.979657530784607]
# loss = 75.920784
# Survived [8] steps
# Total reward [4.375652015209198]
# Survived [1] steps
# Total reward [-0.12036943435668945]
# Survived [1] steps
# Total reward [-0.15194487571716309]
# Survived [15] steps
# Total reward [6.8355393409729]
# Survived [3] steps
# Total reward [1.5526893138885498]
# Survived [2] steps
# Total reward [0.733364462852478]
# Survived [9] steps
# Total reward [5.608949065208435]
# Survived [2] steps
# Total reward [0.7023940086364746]
# Survived [1] steps
# Total reward [-0.15023016929626465]
# Survived [0] steps
# Total reward [-1.0]
# loss = 39.31626
# Survived [7] steps
# Total reward [3.632948160171509]
# Survived [3] steps
# Total reward [1.4597262144088745]
# Survived [2] steps
# Total reward [0.5138583183288574]
# Survived [0] steps
# Total reward [-1.0]
# Survived [6] steps
# Total reward [4.01459264755249]
# Survived [4] steps
# Total reward [1.4883731603622437]
# Survived [7] steps
# Total reward [4.079969525337219]
# Survived [1] steps
# Total reward [-0.14097881317138672]
# Survived [0] steps
# Total reward [-1.0]
# Survived [4] steps
# Total reward [0.74998539686203]
# Survived [1] steps
# Total reward [-0.1344161033630371]
# Survived [6] steps
# Total reward [3.987874388694763]
# Survived [7] steps
# Total reward [4.800055146217346]
# loss = 14.362421
# Survived [2] steps
# Total reward [0.7317714691162109]
# Survived [5] steps
# Total reward [3.245819330215454]
# Survived [3] steps
# Total reward [1.559178113937378]
# Survived [0] steps
# Total reward [-1.0]
# Survived [5] steps
# Total reward [2.883846879005432]
# Survived [1] steps
# Total reward [-0.15593290328979492]
# Survived [6] steps
# Total reward [2.3250686526298523]
# Survived [6] steps
# Total reward [3.8846123218536377]
# Survived [14] steps
# Total reward [5.792573273181915]
# Survived [4] steps
# Total reward [1.662271499633789]
# loss = 10.963735
# Survived [2] steps
# Total reward [0.7169932126998901]
# Survived [3] steps
# Total reward [1.5724749565124512]
# Survived [6] steps
# Total reward [2.432276964187622]
# Survived [3] steps
# Total reward [1.428119421005249]
# Survived [4] steps
# Total reward [2.448655605316162]
# Survived [3] steps
# Total reward [1.4847184419631958]
# Survived [3] steps
# Total reward [1.5188794136047363]
# Survived [3] steps
# Total reward [0.7276545763015747]
# Survived [4] steps
# Total reward [1.680356502532959]
# Survived [1] steps
# Total reward [-0.20651984214782715]
# Survived [1] steps
# Total reward [-0.14224302768707275]
# Survived [3] steps
# Total reward [1.543042778968811]
# Survived [3] steps
# Total reward [1.523803949356079]
# loss = 14.463655
# Survived [13] steps
# Total reward [9.064456343650818]
# Survived [3] steps
# Total reward [1.4720323085784912]
# Survived [6] steps
# Total reward [3.183557450771332]
# Survived [0] steps
# Total reward [-1.0]
# Survived [7] steps
# Total reward [4.706625461578369]
# Survived [6] steps
# Total reward [3.630191206932068]
# Survived [4] steps
# Total reward [2.3908329010009766]
# Survived [0] steps
# Total reward [-1.0]
# Survived [4] steps
# Total reward [1.3682708740234375]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [3] steps
# Total reward [1.4817733764648438]
# Survived [0] steps
# Total reward [-1.0]
# loss = 9.242161
# Survived [5] steps
# Total reward [3.315685272216797]
# Survived [1] steps
# Total reward [-0.13743340969085693]
# Survived [3] steps
# Total reward [1.4100111722946167]
# Survived [3] steps
# Total reward [1.4062998294830322]
# Survived [1] steps
# Total reward [-0.15965735912322998]
# Survived [5] steps
# Total reward [2.457705855369568]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [3] steps
# Total reward [1.5069677829742432]
# Survived [0] steps
# Total reward [-1.0]
# Survived [5] steps
# Total reward [3.2567191123962402]
# Survived [1] steps
# Total reward [-0.18465924263000488]
# Survived [0] steps
# Total reward [-1.0]
# Survived [5] steps
# Total reward [1.6887274980545044]
# Survived [4] steps
# Total reward [1.6739643216133118]
# Step [1000] -- Random [0.9772696540598997]
# Successfully saved model at: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large1000.h5
# Survived [4] steps
# Total reward [2.2778881788253784]
# loss = 20.089355
# Survived [4] steps
# Total reward [2.3435189723968506]
# Survived [5] steps
# Total reward [1.7488799691200256]
# Survived [5] steps
# Total reward [2.3284783363342285]
# Survived [0] steps
# Total reward [-1.0]
# Survived [5] steps
# Total reward [3.313151240348816]
# Survived [1] steps
# Total reward [-0.18087077140808105]
# Survived [2] steps
# Total reward [0.6489338874816895]
# Survived [4] steps
# Total reward [1.4948371052742004]
# Survived [4] steps
# Total reward [1.1734485030174255]
# Survived [3] steps
# Total reward [1.3604069948196411]
# Survived [2] steps
# Total reward [-0.06122791767120361]
# Survived [0] steps
# Total reward [-1.0]
# Survived [5] steps
# Total reward [2.282667338848114]
# Survived [2] steps
# Total reward [0.6809670925140381]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.17084264755249023]
# loss = 15.958597
# Survived [2] steps
# Total reward [0.7125153541564941]
# Survived [8] steps
# Total reward [3.4808874130249023]
# Survived [7] steps
# Total reward [4.100360214710236]
# Survived [2] steps
# Total reward [0.6914925575256348]
# Survived [7] steps
# Total reward [2.298356294631958]
# Survived [8] steps
# Total reward [5.396304965019226]
# Survived [4] steps
# Total reward [1.5339972376823425]
# Survived [10] steps
# Total reward [6.706856608390808]
# loss = 15.662728
# Survived [2] steps
# Total reward [0.6600024700164795]
# Survived [6] steps
# Total reward [3.177198350429535]
# Survived [11] steps
# Total reward [6.466148614883423]
# Survived [4] steps
# Total reward [2.31357204914093]
# Survived [13] steps
# Total reward [8.895161151885986]
# Survived [4] steps
# Total reward [1.5348836779594421]
# loss = 11.772871
# Survived [10] steps
# Total reward [6.740385115146637]
# Survived [6] steps
# Total reward [3.071045756340027]
# Survived [2] steps
# Total reward [0.6706994771957397]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.1413588523864746]
# Survived [1] steps
# Total reward [-0.14769649505615234]
# Survived [1] steps
# Total reward [-0.14565539360046387]
# Survived [4] steps
# Total reward [2.3824340105056763]
# Survived [1] steps
# Total reward [-0.16661882400512695]
# Survived [2] steps
# Total reward [0.6863871812820435]
# Survived [3] steps
# Total reward [0.7575606107711792]
# Survived [7] steps
# Total reward [3.3414849042892456]
# Survived [3] steps
# Total reward [0.6471643447875977]
# Survived [1] steps
# Total reward [-0.14020657539367676]
# Survived [8] steps
# Total reward [4.842340528964996]
# loss = 10.370804
# Survived [3] steps
# Total reward [0.5318202972412109]
# Survived [0] steps
# Total reward [-1.0]
# Survived [3] steps
# Total reward [0.8700860738754272]
# Survived [8] steps
# Total reward [5.601038813591003]
# Survived [3] steps
# Total reward [1.3649630546569824]
# Survived [0] steps
# Total reward [-1.0]
# Survived [11] steps
# Total reward [6.7958598136901855]
# Survived [5] steps
# Total reward [3.012305974960327]
# Survived [1] steps
# Total reward [-0.15267443656921387]
# Survived [0] steps
# Total reward [-1.0]
# Survived [4] steps
# Total reward [1.5074713230133057]
# Survived [1] steps
# Total reward [-0.1524958610534668]
# Survived [1] steps
# Total reward [-0.1579655408859253]
# Survived [2] steps
# Total reward [0.6467881202697754]
# loss = 14.602961
# Survived [3] steps
# Total reward [1.4091321229934692]
# Survived [8] steps
# Total reward [5.458000659942627]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.6685632467269897]
# Survived [7] steps
# Total reward [4.629937291145325]
# Survived [2] steps
# Total reward [0.7066364288330078]
# Survived [1] steps
# Total reward [-0.1425316333770752]
# Survived [5] steps
# Total reward [3.0103342533111572]
# Survived [4] steps
# Total reward [2.4024903774261475]
# Survived [1] steps
# Total reward [-0.17927169799804688]
# Survived [2] steps
# Total reward [0.7054548263549805]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.20822405815124512]
# Survived [0] steps
# Total reward [-1.0]
# Survived [4] steps
# Total reward [2.2180910110473633]
# Survived [0] steps
# Total reward [-1.0]
# loss = 13.355414
# Survived [14] steps
# Total reward [10.961932897567749]
# Survived [3] steps
# Total reward [0.7889144420623779]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.14644896984100342]
# Survived [6] steps
# Total reward [2.888657569885254]
# Survived [1] steps
# Total reward [-0.15675032138824463]
# Survived [3] steps
# Total reward [0.7297734022140503]
# Survived [8] steps
# Total reward [4.029538512229919]
# Survived [3] steps
# Total reward [1.533781886100769]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# loss = 6.5483446
# Survived [9] steps
# Total reward [6.3561625480651855]
# Survived [2] steps
# Total reward [0.6751364469528198]
# Survived [1] steps
# Total reward [-0.1627333164215088]
# Survived [5] steps
# Total reward [3.209308624267578]
# Survived [2] steps
# Total reward [0.6291401386260986]
# Survived [12] steps
# Total reward [9.011964797973633]
# Survived [2] steps
# Total reward [0.6118876934051514]
# Survived [1] steps
# Total reward [-0.17140138149261475]
# Survived [4] steps
# Total reward [1.6227617859840393]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [4] steps
# Total reward [0.7317730188369751]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.7227494716644287]
# loss = 6.8862076
# Survived [3] steps
# Total reward [1.33890700340271]
# Survived [5] steps
# Total reward [3.071800470352173]
# Survived [1] steps
# Total reward [-0.147416353225708]
# Survived [2] steps
# Total reward [0.6834414005279541]
# Survived [1] steps
# Total reward [-0.1690448522567749]
# Survived [6] steps
# Total reward [3.2352306246757507]
# Survived [6] steps
# Total reward [4.013656258583069]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.16612529754638672]
# Survived [4] steps
# Total reward [2.392252206802368]
# Survived [1] steps
# Total reward [-0.1794508695602417]
# Survived [1] steps
# Total reward [-0.1780862808227539]
# Survived [1] steps
# Total reward [-0.18688905239105225]
# Survived [7] steps
# Total reward [4.929104804992676]
# Survived [0] steps
# Total reward [-1.0]
# loss = 9.962711
# Survived [5] steps
# Total reward [3.0169068574905396]
# Survived [2] steps
# Total reward [0.6478850841522217]
# Survived [9] steps
# Total reward [5.862756371498108]
# Survived [10] steps
# Total reward [6.23940497636795]
# Survived [5] steps
# Total reward [3.136323094367981]
# Survived [2] steps
# Total reward [0.6617686748504639]
# Survived [4] steps
# Total reward [2.408950448036194]
# Survived [1] steps
# Total reward [-0.15553486347198486]
# Survived [0] steps
# Total reward [-1.0]
# Survived [4] steps
# Total reward [2.3746237754821777]
# Survived [0] steps
# Total reward [-1.0]
# Survived [4] steps
# Total reward [1.508191704750061]
# loss = 11.421661
# Survived [6] steps
# Total reward [3.267126500606537]
# Survived [1] steps
# Total reward [-0.1590735912322998]
# Survived [0] steps
# Total reward [-1.0]
# Survived [11] steps
# Total reward [7.33277952671051]
# Survived [12] steps
# Total reward [8.537793636322021]
# Survived [3] steps
# Total reward [1.456708550453186]
# Survived [1] steps
# Total reward [-0.3586916923522949]
# Survived [0] steps
# Total reward [-1.0]
# Survived [9] steps
# Total reward [4.758427679538727]
# Survived [2] steps
# Total reward [0.7013050317764282]
# loss = 11.376759
# Survived [4] steps
# Total reward [1.6400665044784546]
# Survived [5] steps
# Total reward [3.1013028621673584]
# Survived [3] steps
# Total reward [1.4315435886383057]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.150618314743042]
# Survived [1] steps
# Total reward [-0.17632794380187988]
# Survived [8] steps
# Total reward [5.648974657058716]
# Survived [11] steps
# Total reward [6.83824360370636]
# Survived [2] steps
# Total reward [0.6233694553375244]
# Survived [2] steps
# Total reward [0.6839863061904907]
# Survived [9] steps
# Total reward [6.323551774024963]
# Survived [0] steps
# Total reward [-1.0]
# loss = 15.147448
# Survived [3] steps
# Total reward [1.500970482826233]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.1453087329864502]
# Survived [1] steps
# Total reward [-0.15439581871032715]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [6] steps
# Total reward [2.3604912161827087]
# Survived [7] steps
# Total reward [4.891786694526672]
# Survived [1] steps
# Total reward [-0.16086363792419434]
# Survived [6] steps
# Total reward [2.5776631236076355]
# Survived [4] steps
# Total reward [2.3318787813186646]
# Survived [3] steps
# Total reward [1.554599642753601]
# Survived [7] steps
# Total reward [4.2508265376091]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.700779914855957]
# Survived [0] steps
# Total reward [-1.0]
# loss = 10.280283
# Survived [1] steps
# Total reward [-0.14705312252044678]
# Survived [2] steps
# Total reward [0.7281219959259033]
# Survived [1] steps
# Total reward [-0.15392041206359863]
# Survived [4] steps
# Total reward [2.264647603034973]
# Survived [15] steps
# Total reward [6.148886620998383]
# Survived [3] steps
# Total reward [1.5631664991378784]
# Survived [3] steps
# Total reward [1.2002453804016113]
# Survived [5] steps
# Total reward [3.3179428577423096]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [-0.029973268508911133]
# Survived [10] steps
# Total reward [5.080901503562927]
# loss = 12.02647
# Survived [0] steps
# Total reward [-1.0]
# Survived [9] steps
# Total reward [3.6534687280654907]
# Survived [1] steps
# Total reward [-0.15353667736053467]
# Survived [4] steps
# Total reward [2.3776527643203735]
# Survived [6] steps
# Total reward [2.2674890756607056]
# Survived [1] steps
# Total reward [-0.15078115463256836]
# Survived [3] steps
# Total reward [1.501882791519165]
# Survived [0] steps
# Total reward [-1.0]
# Survived [7] steps
# Total reward [4.819049000740051]
# Survived [1] steps
# Total reward [-0.15578019618988037]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [3] steps
# Total reward [1.538576602935791]
# Survived [3] steps
# Total reward [1.5052070617675781]
# Survived [1] steps
# Total reward [-0.13396084308624268]
# Survived [0] steps
# Total reward [-1.0]
# loss = 8.134724
# Survived [1] steps
# Total reward [-0.18761730194091797]
# Survived [3] steps
# Total reward [1.526958703994751]
# Survived [7] steps
# Total reward [4.905191779136658]
# Survived [3] steps
# Total reward [0.8091484904289246]
# Survived [3] steps
# Total reward [1.581270694732666]
# Survived [3] steps
# Total reward [1.4623513221740723]
# Survived [3] steps
# Total reward [1.506212830543518]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.7101212739944458]
# Survived [7] steps
# Total reward [4.90270471572876]
# Survived [4] steps
# Total reward [1.666930377483368]
# Survived [1] steps
# Total reward [-0.14519429206848145]
# loss = 8.328426
# Survived [9] steps
# Total reward [6.025784134864807]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.6916854381561279]
# Survived [1] steps
# Total reward [-0.1517035961151123]
# Survived [6] steps
# Total reward [3.931727409362793]
# Survived [1] steps
# Total reward [-0.1535555124282837]
# Survived [5] steps
# Total reward [3.2382782697677612]
# Survived [3] steps
# Total reward [1.2366931438446045]
# Survived [1] steps
# Total reward [-0.17131757736206055]
# Survived [2] steps
# Total reward [0.6976238489151001]
# Survived [0] steps
# Total reward [-1.0]
# Survived [3] steps
# Total reward [1.4923508167266846]
# Survived [1] steps
# Total reward [-0.13586688041687012]
# Survived [3] steps
# Total reward [1.5278866291046143]
# Survived [7] steps
# Total reward [4.556574106216431]
# Survived [1] steps
# Total reward [-0.14233875274658203]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.17977607250213623]
# loss = 11.047222
# Survived [2] steps
# Total reward [0.6640316247940063]
# Survived [3] steps
# Total reward [1.3780317306518555]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.466067910194397]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.6738810539245605]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [8] steps
# Total reward [4.8413044810295105]
# Step [2000] -- Random [0.9229490605723906]
# Successfully saved model at: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large2000.h5
# Survived [19] steps
# Total reward [11.76591032743454]
# loss = 3.1873946
# Survived [13] steps
# Total reward [8.1557657122612]
# Survived [3] steps
# Total reward [1.5736722946166992]
# Survived [3] steps
# Total reward [1.393080472946167]
# Survived [7] steps
# Total reward [4.8694069385528564]
# Survived [5] steps
# Total reward [3.285901427268982]
# Survived [3] steps
# Total reward [1.4525172710418701]
# Survived [1] steps
# Total reward [-0.15144670009613037]
# Survived [6] steps
# Total reward [2.9697694778442383]
# Survived [6] steps
# Total reward [3.412721633911133]
# Survived [1] steps
# Total reward [-0.16146087646484375]
# Survived [1] steps
# Total reward [-0.15256619453430176]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.6864635944366455]
# loss = 0.27300802
# Survived [5] steps
# Total reward [3.065780282020569]
# Survived [1] steps
# Total reward [-0.18028473854064941]
# Survived [2] steps
# Total reward [0.6990174055099487]
# Survived [10] steps
# Total reward [4.34612900018692]
# Survived [4] steps
# Total reward [2.4523892402648926]
# Survived [2] steps
# Total reward [0.6866981983184814]
# Survived [0] steps
# Total reward [-1.0]
# Survived [3] steps
# Total reward [1.6057674884796143]
# Survived [4] steps
# Total reward [2.439466953277588]
# Survived [4] steps
# Total reward [2.3767892122268677]
# Survived [2] steps
# Total reward [0.6622328758239746]
# Survived [3] steps
# Total reward [1.413689136505127]
# Survived [3] steps
# Total reward [1.489308476448059]
# loss = 0.23442948
# Survived [5] steps
# Total reward [3.209783911705017]
# Survived [7] steps
# Total reward [1.9493591785430908]
# Survived [8] steps
# Total reward [4.756865382194519]
# Survived [0] steps
# Total reward [-1.0]
# Survived [3] steps
# Total reward [1.490167260169983]
# Survived [4] steps
# Total reward [1.5469864010810852]
# Survived [1] steps
# Total reward [-0.14842462539672852]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [3] steps
# Total reward [1.28104829788208]
# Survived [1] steps
# Total reward [-0.14140558242797852]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [-0.0870012640953064]
# Survived [4] steps
# Total reward [1.630035638809204]
# Survived [2] steps
# Total reward [0.6532613039016724]
# loss = 0.28754538
# Survived [4] steps
# Total reward [1.6528409719467163]
# Survived [10] steps
# Total reward [5.054058790206909]
# Survived [13] steps
# Total reward [7.316966950893402]
# Survived [3] steps
# Total reward [0.7510529160499573]
# Survived [0] steps
# Total reward [-1.0]
# Survived [7] steps
# Total reward [4.177357733249664]
# Survived [0] steps
# Total reward [-1.0]
# Survived [7] steps
# Total reward [3.343180000782013]
# Survived [1] steps
# Total reward [-0.15745925903320312]
# loss = 0.11748464
# Survived [4] steps
# Total reward [2.1499149799346924]
# Survived [2] steps
# Total reward [0.6789336204528809]
# Survived [3] steps
# Total reward [1.572357177734375]
# Survived [3] steps
# Total reward [1.4515798091888428]
# Survived [3] steps
# Total reward [1.2907183170318604]
# Survived [0] steps
# Total reward [-1.0]
# Survived [9] steps
# Total reward [5.739891052246094]
# Survived [7] steps
# Total reward [3.2693586945533752]
# Survived [4] steps
# Total reward [2.39519464969635]
# Survived [5] steps
# Total reward [3.257106304168701]
# Survived [3] steps
# Total reward [1.4895141124725342]
# loss = 0.27183682
# Survived [5] steps
# Total reward [2.9277957677841187]
# Survived [1] steps
# Total reward [-0.13910508155822754]
# Survived [7] steps
# Total reward [4.199238717556]
# Survived [1] steps
# Total reward [-0.1429370641708374]
# Survived [2] steps
# Total reward [0.6264233589172363]
# Survived [8] steps
# Total reward [4.724355638027191]
# Survived [0] steps
# Total reward [-1.0]
# Survived [7] steps
# Total reward [3.216914176940918]
# Survived [6] steps
# Total reward [3.1123156547546387]
# Survived [4] steps
# Total reward [1.629421055316925]
# Survived [1] steps
# Total reward [-0.20901024341583252]
# Survived [1] steps
# Total reward [-0.1322413682937622]
# loss = 0.13654089
# Survived [7] steps
# Total reward [4.987939119338989]
# Survived [1] steps
# Total reward [-0.16692578792572021]
# Survived [0] steps
# Total reward [-1.0]
# Survived [7] steps
# Total reward [3.0449761748313904]
# Survived [5] steps
# Total reward [3.081574320793152]
# Survived [1] steps
# Total reward [-0.1393566131591797]
# Survived [3] steps
# Total reward [1.541353702545166]
# Survived [2] steps
# Total reward [0.7046149969100952]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.6414496898651123]
# Survived [15] steps
# Total reward [7.9938448667526245]
# Survived [6] steps
# Total reward [3.3934107422828674]
# loss = 0.14952317
# Survived [3] steps
# Total reward [0.7598806023597717]
# Survived [0] steps
# Total reward [-1.0]
# Survived [13] steps
# Total reward [8.516522705554962]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.6336669921875]
# Survived [13] steps
# Total reward [9.090046763420105]
# Survived [13] steps
# Total reward [7.562339663505554]
# loss = 0.29897463
# Survived [7] steps
# Total reward [4.994860887527466]
# Survived [2] steps
# Total reward [0.6412404775619507]
# Survived [6] steps
# Total reward [3.3663137555122375]
# Survived [3] steps
# Total reward [1.4027810096740723]
# Survived [1] steps
# Total reward [-0.17344307899475098]
# Survived [3] steps
# Total reward [1.5876615047454834]
# Survived [1] steps
# Total reward [-0.15778589248657227]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.7235370874404907]
# Survived [14] steps
# Total reward [9.333529353141785]
# Survived [3] steps
# Total reward [1.4392521381378174]
# Survived [1] steps
# Total reward [-0.14742612838745117]
# Survived [0] steps
# Total reward [-1.0]
# loss = 0.14560932
# Survived [7] steps
# Total reward [4.917371392250061]
# Survived [0] steps
# Total reward [-1.0]
# Survived [3] steps
# Total reward [1.4053826332092285]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.1578538417816162]
# Survived [3] steps
# Total reward [1.5057786703109741]
# Survived [1] steps
# Total reward [-0.23007237911224365]
# Survived [6] steps
# Total reward [1.4287232756614685]
# Survived [1] steps
# Total reward [-0.12545526027679443]
# Survived [3] steps
# Total reward [1.4241163730621338]
# Survived [10] steps
# Total reward [6.632669985294342]
# Survived [3] steps
# Total reward [1.5989384651184082]
# Survived [1] steps
# Total reward [-0.14165687561035156]
# Survived [6] steps
# Total reward [3.852689266204834]
# Survived [2] steps
# Total reward [0.6764733791351318]
# loss = 0.12978137
# Survived [4] steps
# Total reward [2.2694671154022217]
# Survived [3] steps
# Total reward [1.4194283485412598]
# Survived [2] steps
# Total reward [0.7181048393249512]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.7441306114196777]
# Survived [0] steps
# Total reward [-1.0]
# Survived [3] steps
# Total reward [1.4804214239120483]
# Survived [5] steps
# Total reward [2.356210470199585]
# Survived [6] steps
# Total reward [3.9870989322662354]
# Survived [2] steps
# Total reward [0.6778465509414673]
# Survived [2] steps
# Total reward [0.7406636476516724]
# Survived [11] steps
# Total reward [7.356391429901123]
# Survived [1] steps
# Total reward [-0.17416644096374512]
# loss = 0.08856954
# Survived [3] steps
# Total reward [1.454369306564331]
# Survived [1] steps
# Total reward [-0.16972732543945312]
# Survived [3] steps
# Total reward [1.3647164106369019]
# Survived [0] steps
# Total reward [-1.0]
# Survived [7] steps
# Total reward [3.559803068637848]
# Survived [4] steps
# Total reward [1.9077255725860596]
# Survived [4] steps
# Total reward [1.0867409706115723]
# Survived [4] steps
# Total reward [1.8395987749099731]
# Survived [0] steps
# Total reward [-1.0]
# Survived [6] steps
# Total reward [2.7227535247802734]
# Survived [3] steps
# Total reward [0.34703296422958374]
# Survived [2] steps
# Total reward [0.4009910821914673]
# Survived [2] steps
# Total reward [0.5189754962921143]
# Survived [2] steps
# Total reward [0.5006242990493774]
# loss = 0.06852691
# Survived [10] steps
# Total reward [5.276244938373566]
# Survived [1] steps
# Total reward [-0.23848628997802734]
# Survived [7] steps
# Total reward [3.269508421421051]
# Survived [1] steps
# Total reward [-0.271378755569458]
# Survived [3] steps
# Total reward [1.0551307201385498]
# Survived [2] steps
# Total reward [0.45602989196777344]
# Survived [5] steps
# Total reward [2.468019127845764]
# Survived [3] steps
# Total reward [1.0037000179290771]
# Survived [6] steps
# Total reward [3.258805513381958]
# Survived [3] steps
# Total reward [1.0941479206085205]
# Survived [3] steps
# Total reward [1.2026067972183228]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.49754416942596436]
# loss = 0.1007042
# Survived [5] steps
# Total reward [2.8655102252960205]
# Survived [3] steps
# Total reward [0.9020577669143677]
# Survived [6] steps
# Total reward [1.1697173118591309]
# Survived [1] steps
# Total reward [-0.2693312168121338]
# Survived [2] steps
# Total reward [0.44004690647125244]
# Survived [7] steps
# Total reward [3.254329562187195]
# Survived [9] steps
# Total reward [4.216187357902527]
# Survived [3] steps
# Total reward [1.1084105968475342]
# Survived [3] steps
# Total reward [1.009189248085022]
# Survived [2] steps
# Total reward [0.506483793258667]
# Survived [3] steps
# Total reward [0.46900659799575806]
# Survived [0] steps
# Total reward [-1.0]
# loss = 0.24741152
# Survived [6] steps
# Total reward [3.437736988067627]
# Survived [1] steps
# Total reward [-0.2745555639266968]
# Survived [15] steps
# Total reward [7.369515478610992]
# Survived [0] steps
# Total reward [-1.0]
# Survived [6] steps
# Total reward [3.308266043663025]
# Survived [4] steps
# Total reward [1.9890795946121216]
# Survived [3] steps
# Total reward [0.23411977291107178]
# Survived [5] steps
# Total reward [2.659537196159363]
# Survived [4] steps
# Total reward [1.9278028011322021]
# Survived [0] steps
# Total reward [-1.0]
# loss = 0.23192748
# Survived [5] steps
# Total reward [1.898394227027893]
# Survived [3] steps
# Total reward [1.0257930755615234]
# Survived [9] steps
# Total reward [5.68080461025238]
# Survived [1] steps
# Total reward [-0.30847668647766113]
# Survived [5] steps
# Total reward [2.42117977142334]
# Survived [3] steps
# Total reward [1.1288243532180786]
# Survived [4] steps
# Total reward [1.8032276630401611]
# Survived [14] steps
# Total reward [6.591603696346283]
# loss = 0.08451608
# Survived [9] steps
# Total reward [3.5239354372024536]
# Survived [8] steps
# Total reward [4.348407864570618]
# Survived [1] steps
# Total reward [-0.27950942516326904]
# Survived [3] steps
# Total reward [1.2291063070297241]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.24860835075378418]
# Survived [0] steps
# Total reward [-1.0]
# Survived [3] steps
# Total reward [1.1944464445114136]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.5179250240325928]
# Survived [0] steps
# Total reward [-1.0]
# Survived [5] steps
# Total reward [2.7297314405441284]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.38536882400512695]
# Survived [7] steps
# Total reward [2.707671344280243]
# Survived [2] steps
# Total reward [0.1219857931137085]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.26595211029052734]
# loss = 0.14642222
# Survived [1] steps
# Total reward [-0.27149367332458496]
# Survived [4] steps
# Total reward [1.0320287346839905]
# Survived [4] steps
# Total reward [1.9699293375015259]
# Survived [2] steps
# Total reward [0.40948665142059326]
# Survived [3] steps
# Total reward [1.1929305791854858]
# Survived [5] steps
# Total reward [2.279304265975952]
# Survived [3] steps
# Total reward [1.2094078063964844]
# Step [3000] -- Random [0.874727974286106]
# Survived [3] steps
# Total reward [1.2126041650772095]
# Successfully saved model at: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large3000.h5
# Survived [1] steps
# Total reward [-0.27779173851013184]
# Survived [7] steps
# Total reward [3.335113823413849]
# Survived [2] steps
# Total reward [0.22797727584838867]
# Survived [2] steps
# Total reward [0.497397780418396]
# Survived [6] steps
# Total reward [1.804103136062622]
# loss = 0.21138404
# Survived [4] steps
# Total reward [1.1792982816696167]
# Survived [3] steps
# Total reward [1.1913280487060547]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.2682209014892578]
# Survived [6] steps
# Total reward [2.580910801887512]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [5] steps
# Total reward [1.55534428358078]
# Survived [4] steps
# Total reward [1.803800106048584]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.23551416397094727]
# Survived [3] steps
# Total reward [1.218912124633789]
# Survived [2] steps
# Total reward [0.43099451065063477]
# Survived [2] steps
# Total reward [0.40762197971343994]
# Survived [1] steps
# Total reward [-0.23822391033172607]
# loss = 0.12019362
# Survived [8] steps
# Total reward [3.553143560886383]
# Survived [3] steps
# Total reward [0.9792439937591553]
# Survived [2] steps
# Total reward [0.43170666694641113]
# Survived [3] steps
# Total reward [1.189414143562317]
# Survived [3] steps
# Total reward [0.9799165725708008]
# Survived [4] steps
# Total reward [1.9532650709152222]
# Survived [3] steps
# Total reward [1.2216689586639404]
# Survived [5] steps
# Total reward [1.866615116596222]
# Survived [6] steps
# Total reward [3.412947654724121]
# Survived [0] steps
# Total reward [-1.0]
# Survived [7] steps
# Total reward [3.5044385194778442]
# Survived [6] steps
# Total reward [1.740193247795105]
# loss = 0.13662535
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [12] steps
# Total reward [6.90833592414856]
# Survived [2] steps
# Total reward [0.4610774517059326]
# Survived [8] steps
# Total reward [3.7125660181045532]
# Survived [1] steps
# Total reward [-0.24405670166015625]
# Survived [12] steps
# Total reward [7.19341254234314]
# Survived [4] steps
# Total reward [1.9449775218963623]
# loss = 0.10923528
# Survived [16] steps
# Total reward [8.54457139968872]
# Survived [5] steps
# Total reward [2.058709502220154]
# Survived [2] steps
# Total reward [0.5019965171813965]
# Survived [1] steps
# Total reward [-0.2555443048477173]
# Survived [1] steps
# Total reward [-0.25043344497680664]
# Survived [7] steps
# Total reward [1.6823797821998596]
# Survived [8] steps
# Total reward [4.625199794769287]
# Survived [6] steps
# Total reward [1.9686633348464966]
# Survived [5] steps
# Total reward [1.8675814270973206]
# Survived [1] steps
# Total reward [-0.287386417388916]
# loss = 0.092752516
# Survived [3] steps
# Total reward [1.1389955282211304]
# Survived [3] steps
# Total reward [0.4567820429801941]
# Survived [1] steps
# Total reward [-0.26269984245300293]
# Survived [4] steps
# Total reward [1.920843482017517]
# Survived [3] steps
# Total reward [1.2717876434326172]
# Survived [4] steps
# Total reward [1.620124340057373]
# Survived [5] steps
# Total reward [2.754396438598633]
# Survived [1] steps
# Total reward [-0.278125524520874]
# Survived [3] steps
# Total reward [1.1931310892105103]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.2587778568267822]
# Survived [3] steps
# Total reward [0.7428933382034302]
# Survived [8] steps
# Total reward [4.5313416719436646]
# loss = 0.070762016
# Survived [7] steps
# Total reward [3.580337643623352]
# Survived [1] steps
# Total reward [-0.24228739738464355]
# Survived [6] steps
# Total reward [2.5423659086227417]
# Survived [7] steps
# Total reward [3.175075590610504]
# Survived [5] steps
# Total reward [1.984264612197876]
# Survived [8] steps
# Total reward [4.105791985988617]
# Survived [9] steps
# Total reward [4.9396679401397705]
# Survived [4] steps
# Total reward [1.1040832996368408]
# Survived [2] steps
# Total reward [0.36387741565704346]
# loss = 0.050950877
# Survived [6] steps
# Total reward [3.2292211055755615]
# Survived [3] steps
# Total reward [1.219512701034546]
# Survived [7] steps
# Total reward [4.163290619850159]
# Survived [6] steps
# Total reward [1.0838138461112976]
# Survived [4] steps
# Total reward [0.5970750451087952]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.3982774019241333]
# Survived [0] steps
# Total reward [-1.0]
# Survived [5] steps
# Total reward [1.7713363766670227]
# Survived [4] steps
# Total reward [1.969468116760254]
# Survived [4] steps
# Total reward [1.8170418739318848]
# Survived [5] steps
# Total reward [2.6502468585968018]
# loss = 0.19850472
# Survived [5] steps
# Total reward [2.771753668785095]
# Survived [5] steps
# Total reward [2.638356566429138]
# Survived [2] steps
# Total reward [0.4347496032714844]
# Survived [3] steps
# Total reward [1.0298188924789429]
# Survived [3] steps
# Total reward [1.1820697784423828]
# Survived [3] steps
# Total reward [1.2386939525604248]
# Survived [3] steps
# Total reward [1.161984920501709]
# Survived [6] steps
# Total reward [3.4704999923706055]
# Survived [0] steps
# Total reward [-1.0]
# Survived [7] steps
# Total reward [3.2497053742408752]
# Survived [5] steps
# Total reward [1.9833717942237854]
# loss = 0.05241981
# Survived [8] steps
# Total reward [3.3272558450698853]
# Survived [3] steps
# Total reward [1.2088099718093872]
# Survived [7] steps
# Total reward [2.603333532810211]
# Survived [2] steps
# Total reward [0.511278510093689]
# Survived [1] steps
# Total reward [-0.25375163555145264]
# Survived [1] steps
# Total reward [-0.27000975608825684]
# Survived [9] steps
# Total reward [4.410806059837341]
# Survived [4] steps
# Total reward [2.188848853111267]
# Survived [8] steps
# Total reward [4.685079276561737]
# Survived [7] steps
# Total reward [3.1477065086364746]
# loss = 0.051613484
# Survived [8] steps
# Total reward [4.6066272258758545]
# Survived [5] steps
# Total reward [2.134904205799103]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [4] steps
# Total reward [1.8916622400283813]
# Survived [0] steps
# Total reward [-1.0]
# Survived [13] steps
# Total reward [8.28409743309021]
# Survived [0] steps
# Total reward [-1.0]
# Survived [3] steps
# Total reward [1.384739875793457]
# Survived [0] steps
# Total reward [-1.0]
# Survived [3] steps
# Total reward [1.065414309501648]
# Survived [3] steps
# Total reward [0.5139130353927612]
# Survived [1] steps
# Total reward [-0.1614527702331543]
# loss = 0.043600257
# Survived [10] steps
# Total reward [6.638143181800842]
# Survived [7] steps
# Total reward [4.680437445640564]
# Survived [3] steps
# Total reward [1.4360843896865845]
# Survived [4] steps
# Total reward [1.4198877215385437]
# Survived [5] steps
# Total reward [2.903340458869934]
# Survived [1] steps
# Total reward [-0.21965408325195312]
# Survived [4] steps
# Total reward [2.172192931175232]
# Survived [5] steps
# Total reward [2.9682929515838623]
# Survived [3] steps
# Total reward [1.2890502214431763]
# Survived [7] steps
# Total reward [3.667703926563263]
# loss = 0.048917543
# Survived [12] steps
# Total reward [6.2636454701423645]
# Survived [4] steps
# Total reward [0.7239509224891663]
# Survived [1] steps
# Total reward [-0.19091296195983887]
# Survived [2] steps
# Total reward [0.6094377040863037]
# Survived [7] steps
# Total reward [4.072410821914673]
# Survived [4] steps
# Total reward [1.1978846192359924]
# Survived [2] steps
# Total reward [0.6322329044342041]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.6549504995346069]
# Survived [7] steps
# Total reward [4.399864315986633]
# Survived [3] steps
# Total reward [1.3384103775024414]
# Survived [0] steps
# Total reward [-1.0]
# loss = 0.09214581
# Survived [2] steps
# Total reward [0.665221095085144]
# Survived [4] steps
# Total reward [2.1200605630874634]
# Survived [1] steps
# Total reward [-0.18457627296447754]
# Survived [2] steps
# Total reward [0.6995271444320679]
# Survived [6] steps
# Total reward [3.5491706132888794]
# Survived [6] steps
# Total reward [3.839210629463196]
# Survived [1] steps
# Total reward [-0.1527320146560669]
# Survived [7] steps
# Total reward [2.11467969417572]
# Survived [1] steps
# Total reward [-0.18410062789916992]
# Survived [1] steps
# Total reward [-0.15484952926635742]
# Survived [2] steps
# Total reward [-0.14121216535568237]
# Survived [1] steps
# Total reward [-0.19843316078186035]
# Survived [1] steps
# Total reward [-0.14463043212890625]
# Survived [3] steps
# Total reward [1.3170796632766724]
# Survived [5] steps
# Total reward [1.8314873576164246]
# loss = 0.05831642
# Survived [0] steps
# Total reward [-1.0]
# Survived [6] steps
# Total reward [3.6518315076828003]
# Survived [11] steps
# Total reward [6.3634690046310425]
# Survived [4] steps
# Total reward [1.7648937702178955]
# Survived [0] steps
# Total reward [-1.0]
# Survived [9] steps
# Total reward [5.9408427476882935]
# Survived [8] steps
# Total reward [4.184983789920807]
# Survived [3] steps
# Total reward [1.0941121578216553]
# Survived [4] steps
# Total reward [2.107207179069519]
# loss = 0.05158362
# Survived [4] steps
# Total reward [1.5276368260383606]
# Survived [0] steps
# Total reward [-1.0]
# Survived [6] steps
# Total reward [2.8340246081352234]
# Survived [2] steps
# Total reward [0.6007406711578369]
# Survived [1] steps
# Total reward [-0.17590057849884033]
# Survived [1] steps
# Total reward [-0.23081529140472412]
# Survived [8] steps
# Total reward [4.212289273738861]
# Survived [9] steps
# Total reward [6.251743674278259]
# Survived [5] steps
# Total reward [2.939705491065979]
# Survived [1] steps
# Total reward [-0.15439891815185547]
# Survived [9] steps
# Total reward [5.958196043968201]
# loss = 0.035064407
# Survived [5] steps
# Total reward [2.3877119421958923]
# Survived [3] steps
# Total reward [1.2277536392211914]
# Survived [9] steps
# Total reward [5.1530921459198]
# Survived [2] steps
# Total reward [0.6419488191604614]
# Survived [3] steps
# Total reward [1.443804144859314]
# Survived [3] steps
# Total reward [0.7065398693084717]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.17634224891662598]
# Survived [8] steps
# Total reward [5.059297442436218]
# Survived [3] steps
# Total reward [0.7799212336540222]
# Survived [4] steps
# Total reward [1.933830738067627]
# Survived [4] steps
# Total reward [2.209325671195984]
# loss = 0.059135504
# Survived [4] steps
# Total reward [2.0993733406066895]
# Survived [1] steps
# Total reward [-0.1648409366607666]
# Survived [2] steps
# Total reward [0.6182819604873657]
# Survived [7] steps
# Total reward [4.785693287849426]
# Survived [2] steps
# Total reward [0.6327810287475586]
# Survived [0] steps
# Total reward [-1.0]
# Survived [4] steps
# Total reward [1.314418613910675]
# Survived [5] steps
# Total reward [2.9155194759368896]
# Survived [6] steps
# Total reward [2.956156075000763]
# Survived [3] steps
# Total reward [1.4158815145492554]
# Survived [3] steps
# Total reward [1.2869793176651]
# Survived [4] steps
# Total reward [1.2263274788856506]
# Survived [0] steps
# Total reward [-1.0]
# loss = 0.18019925
# Survived [4] steps
# Total reward [2.203933358192444]
# Survived [9] steps
# Total reward [5.091125071048737]
# Survived [1] steps
# Total reward [-0.21434402465820312]
# Survived [0] steps
# Total reward [-1.0]
# Survived [6] steps
# Total reward [3.819585919380188]
# Survived [0] steps
# Total reward [-1.0]
# Step [4000] -- Random [0.8313738419146323]
# Successfully saved model at: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large4000.h5
# Survived [4] steps
# Total reward [2.1925106048583984]
# Survived [7] steps
# Total reward [3.4542860984802246]
# Survived [5] steps
# Total reward [2.751859426498413]
# Survived [3] steps
# Total reward [1.4585621356964111]
# Survived [2] steps
# Total reward [0.7123063802719116]
# Survived [4] steps
# Total reward [1.5615615844726562]
# Survived [0] steps
# Total reward [-1.0]
# loss = 0.062770456
# Survived [8] steps
# Total reward [3.664406895637512]
# Survived [5] steps
# Total reward [3.009963274002075]
# Survived [6] steps
# Total reward [3.7753632068634033]
# Survived [3] steps
# Total reward [1.465323567390442]
# Survived [15] steps
# Total reward [10.809870958328247]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [0] steps
# Total reward [-1.0]
# Survived [4] steps
# Total reward [1.9055784940719604]
# Survived [4] steps
# Total reward [2.0985406637191772]
# loss = 0.08684757
# Survived [7] steps
# Total reward [2.9177759885787964]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.22440052032470703]
# Survived [8] steps
# Total reward [4.4265806674957275]
# Survived [5] steps
# Total reward [2.6644670963287354]
# Survived [1] steps
# Total reward [-0.15294408798217773]
# Survived [0] steps
# Total reward [-1.0]
# Survived [2] steps
# Total reward [0.6781350374221802]
# Survived [6] steps
# Total reward [3.9562270641326904]
# Survived [0] steps
# Total reward [-1.0]
# Survived [1] steps
# Total reward [-0.15155386924743652]
# Survived [2] steps
# Total reward [0.6682254076004028]
# Survived [4] steps
# Total reward [2.1790965795516968]
# Survived [4] steps
# Total reward [2.1339672803878784]
# loss = 0.07187717
# Survived [3] steps
# Total reward [1.1472994089126587]
# ...
# loss = 0.000809868
# Survived [86] steps
# Total reward [26.687742590904236]
# loss = 0.0002729544
# loss = 0.0015708159
# Survived [128] steps
# Total reward [40.082319140434265]
# Survived [6] steps
# Total reward [2.536827504634857]
# loss = 0.0011120406
# loss = 0.00087054074
# loss = 0.0004778204
# Survived [129] steps
# Total reward [113.2915107011795]
# Survived [3] steps
# Total reward [1.5471084117889404]
# Step [145000] -- Random [0.001]
# Successfully saved model at: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large145000.h5
# Survived [3] steps
# Total reward [1.5537837743759155]
# loss = 0.0005369469
# loss = 0.0012254254
# Survived [129] steps
# Total reward [43.81403136253357]
# loss = 0.00032570952
# Survived [51] steps
# Total reward [16.947366774082184]
# loss = 0.00044998538
# loss = 0.0006149473
# Survived [110] steps
# Total reward [87.87584894895554]
# loss = 0.00048159435
# loss = 0.0005211934
# Survived [120] steps
# Total reward [44.021688520908356]
# Survived [3] steps
# Total reward [1.5557559728622437]
# Survived [6] steps
# Total reward [2.2989566326141357]
# Survived [3] steps
# Total reward [1.5478227138519287]
# loss = 0.0006020664
# loss = 0.0006546824
# loss = 0.0004333814
# Survived [129] steps
# Total reward [42.59037321805954]
# loss = 0.0011014299
# loss = 0.0004950556
# Survived [99] steps
# Total reward [30.315395414829254]
# Survived [3] steps
# Total reward [1.5247819423675537]
# Survived [21] steps
# Total reward [17.123074531555176]
# loss = 0.00033648527
# loss = 0.00094084966
# Survived [128] steps
# Total reward [41.40451544523239]
# Survived [6] steps
# Total reward [2.497752010822296]
# loss = 0.0010181937
# loss = 0.003837663
# loss = 0.001087609
# Survived [131] steps
# Total reward [42.69117373228073]
# Survived [6] steps
# Total reward [2.6308860778808594]
# loss = 0.0011449335
# Step [146000] -- Random [0.001]
# Successfully saved model at: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large146000.h5
# loss = 0.0012843944
# Survived [129] steps
# Total reward [45.53405457735062]
# loss = 0.00056475005
# loss = 0.00055753265
# Survived [115] steps
# Total reward [50.37695920467377]
# loss = 0.0026738644
# loss = 0.0010413047
# Survived [111] steps
# Total reward [36.54501390457153]
# loss = 0.002018483
# Survived [7] steps
# Total reward [3.2641205191612244]
# loss = 0.0011905713
# loss = 0.00014916339
# Survived [118] steps
# Total reward [38.738544046878815]
# Survived [3] steps
# Total reward [1.5023837089538574]
# loss = 0.0016056907
# Survived [86] steps
# Total reward [28.363504767417908]
# loss = 0.0008062269
# Survived [18] steps
# Total reward [5.1491798758506775]
# Survived [41] steps
# Total reward [13.517586588859558]
# loss = 0.0020318425
# loss = 0.00091588276
# loss = 0.0009403652
# loss = 0.00039209856
# loss = 0.0005729026
# Survived [256] steps
# Total reward [84.04776412248611]
# loss = 0.0011975253
# loss = 0.0003583728
# Survived [128] steps
# Total reward [102.29955387115479]
# Step [147000] -- Random [0.001]
# loss = 0.0022101707
# Successfully saved model at: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large147000.h5
# loss = 0.00050287886
# loss = 0.0001322385
# loss = 0.00096279604
# loss = 0.0009624367
# Survived [258] steps
# Total reward [106.17045253515244]
# Survived [5] steps
# Total reward [3.216460943222046]
# loss = 0.0010726679
# Survived [31] steps
# Total reward [11.582866907119751]
# Survived [39] steps
# Total reward [28.379633486270905]
# Survived [6] steps
# Total reward [2.536085546016693]
# loss = 0.0020300797
# loss = 0.000289117
# loss = 0.0006137034
# loss = 0.0014021512
# loss = 0.0004235822
# Survived [280] steps
# Total reward [111.43982690572739]
# loss = 0.00051547843
# Survived [14] steps
# Total reward [5.609996199607849]
# Survived [14] steps
# Total reward [5.803453624248505]
# loss = 9.494771e-05
# Survived [81] steps
# Total reward [41.5682048201561]
# loss = 0.0038553262
# Survived [6] steps
# Total reward [2.6820095777511597]
# Survived [6] steps
# Total reward [2.642934203147888]
# Survived [7] steps
# Total reward [3.4516895413398743]
# Survived [13] steps
# Total reward [5.682903826236725]
# Survived [14] steps
# Total reward [5.782012403011322]
# Survived [3] steps
# Total reward [1.5608675479888916]
# loss = 0.0013088279
# Survived [7] steps
# Total reward [3.5023582577705383]
# Survived [6] steps
# Total reward [3.3764036893844604]
# Survived [5] steps
# Total reward [3.2205960750579834]
# Survived [6] steps
# Total reward [3.3543288707733154]
# Survived [8] steps
# Total reward [4.262643456459045]
# Survived [7] steps
# Total reward [3.386654853820801]
# Survived [4] steps
# Total reward [2.442354440689087]
# Survived [4] steps
# Total reward [2.4205883741378784]
# Survived [6] steps
# Total reward [3.3125850558280945]
# loss = 0.0013455619
# Survived [6] steps
# Total reward [3.9613484144210815]
# Survived [3] steps
# Total reward [1.5986227989196777]
# Survived [3] steps
# Total reward [1.5283712148666382]
# Survived [6] steps
# Total reward [2.7248423099517822]
# Survived [3] steps
# Total reward [1.5973567962646484]
# Survived [3] steps
# Total reward [1.5623881816864014]
# Survived [3] steps
# Total reward [1.5836042165756226]
# Survived [3] steps
# Total reward [1.5388107299804688]
# Survived [3] steps
# Total reward [1.5950924158096313]
# Survived [3] steps
# Total reward [1.5819687843322754]
# Survived [8] steps
# Total reward [4.242370545864105]
# loss = 0.0007008808
# Survived [11] steps
# Total reward [5.11963564157486]
# Survived [6] steps
# Total reward [3.380050003528595]
# Survived [3] steps
# Total reward [1.555357813835144]
# Survived [4] steps
# Total reward [2.4503761529922485]
# Survived [7] steps
# Total reward [3.4527562856674194]
# Survived [4] steps
# Total reward [2.4421546459198]
# Survived [3] steps
# Total reward [1.5882835388183594]
# Survived [3] steps
# Total reward [1.5896434783935547]
# Survived [7] steps
# Total reward [4.1028395891189575]
# loss = 0.002098748
# Survived [3] steps
# Total reward [1.6058846712112427]
# Survived [3] steps
# Total reward [1.5638972520828247]
# Survived [4] steps
# Total reward [2.2838597297668457]
# Survived [5] steps
# Total reward [3.2430025339126587]
# Survived [3] steps
# Total reward [1.5912275314331055]
# Survived [11] steps
# Total reward [5.956073343753815]
# Survived [3] steps
# Total reward [1.5666674375534058]
# Survived [3] steps
# Total reward [1.592213749885559]
# Step [148000] -- Random [0.001]
# Survived [5] steps
# Total reward [3.0876020193099976]
# Successfully saved model at: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large148000.h5
# Survived [3] steps
# Total reward [1.5835630893707275]
# loss = 0.0012206933
# Survived [13] steps
# Total reward [5.220434546470642]
# Survived [3] steps
# Total reward [1.6238758563995361]
# Survived [7] steps
# Total reward [3.5058352947235107]
# Survived [3] steps
# Total reward [1.6122756004333496]
# Survived [12] steps
# Total reward [4.512312114238739]
# Survived [10] steps
# Total reward [5.838975012302399]
# loss = 0.0012625549
# Survived [6] steps
# Total reward [4.006470084190369]
# Survived [17] steps
# Total reward [7.946453750133514]
# Survived [10] steps
# Total reward [3.3930693864822388]
# Survived [5] steps
# Total reward [3.2182942628860474]
# Survived [15] steps
# Total reward [5.073169410228729]
# loss = 0.0020551912
# Survived [13] steps
# Total reward [4.587874174118042]
# Survived [5] steps
# Total reward [2.417223274707794]
# Survived [7] steps
# Total reward [4.949691295623779]
# Survived [26] steps
# Total reward [9.103213846683502]
# loss = 0.0027152048
# Survived [10] steps
# Total reward [4.893466055393219]
# Survived [8] steps
# Total reward [4.585545063018799]
# Survived [26] steps
# Total reward [10.286646127700806]
# Survived [5] steps
# Total reward [2.4792036414146423]
# loss = 0.0011951636
# Survived [31] steps
# Total reward [11.007100403308868]
# loss = 0.0016825496
# Survived [49] steps
# Total reward [20.596704959869385]
# Survived [8] steps
# Total reward [4.711957156658173]
# Survived [17] steps
# Total reward [7.21705961227417]
# Survived [8] steps
# Total reward [3.2311490774154663]
# loss = 0.0017546858
# Survived [3] steps
# Total reward [1.596219539642334]
# Survived [3] steps
# Total reward [1.5153498649597168]
# Survived [3] steps
# Total reward [1.5667487382888794]
# Survived [17] steps
# Total reward [7.078429102897644]
# Survived [9] steps
# Total reward [4.844291090965271]
# Survived [3] steps
# Total reward [1.5653289556503296]
# Survived [8] steps
# Total reward [4.01150518655777]
# loss = 0.0020778787
# Survived [16] steps
# Total reward [5.839568316936493]
# Survived [3] steps
# Total reward [1.5597844123840332]
# Survived [8] steps
# Total reward [4.333661258220673]
# Survived [3] steps
# Total reward [1.594909429550171]
# Survived [3] steps
# Total reward [1.5700500011444092]
# Survived [17] steps
# Total reward [7.430241584777832]
# loss = 0.002553342
# Survived [51] steps
# Total reward [15.34503710269928]
# loss = 0.0011812518
# Survived [20] steps
# Total reward [7.404804468154907]
# Survived [3] steps
# Total reward [1.5820754766464233]
# Survived [3] steps
# Total reward [1.5541316270828247]
# Survived [14] steps
# Total reward [5.345837354660034]
# Survived [6] steps
# Total reward [3.259606957435608]
# Survived [6] steps
# Total reward [3.3636122941970825]
# loss = 0.00094947126
# Survived [6] steps
# Total reward [3.3415496349334717]
# Survived [3] steps
# Total reward [1.5818488597869873]
# Survived [6] steps
# Total reward [3.2596081495285034]
# Survived [3] steps
# Total reward [1.5821599960327148]
# Survived [3] steps
# Total reward [1.5608991384506226]
# Survived [3] steps
# Total reward [1.5775419473648071]
# Survived [6] steps
# Total reward [3.219887375831604]
# Survived [6] steps
# Total reward [2.906753897666931]
# Survived [6] steps
# Total reward [2.9343684315681458]
# Survived [6] steps
# Total reward [3.0555129051208496]
# Survived [3] steps
# Total reward [1.5724657773971558]
# loss = 0.0012138656
# Survived [3] steps
# Total reward [1.5422214269638062]
# Survived [5] steps
# Total reward [3.1628342866897583]
# Survived [6] steps
# Total reward [2.9115968346595764]
# Survived [5] steps
# Total reward [3.1121326684951782]
# Survived [3] steps
# Total reward [1.5453563928604126]
# Survived [3] steps
# Total reward [1.5261750221252441]
# Survived [6] steps
# Total reward [2.20078045129776]
# Survived [6] steps
# Total reward [2.8556056022644043]
# Survived [6] steps
# Total reward [3.3380127549171448]
# Survived [3] steps
# Total reward [1.5850019454956055]
# loss = 0.0020049235
# Survived [18] steps
# Total reward [7.385149359703064]
# Survived [6] steps
# Total reward [3.7202160358428955]
# Survived [3] steps
# Total reward [1.4944608211517334]
# Survived [6] steps
# Total reward [2.9612215757369995]
# Survived [6] steps
# Total reward [2.949514091014862]
# Survived [6] steps
# Total reward [3.1871731281280518]
# loss = 0.0026800828
# Survived [43] steps
# Total reward [14.734374403953552]
# loss = 0.001589558
# Survived [26] steps
# Total reward [9.086638510227203]
# Survived [19] steps
# Total reward [8.585868656635284]
# Survived [18] steps
# Total reward [6.9718562960624695]
# loss = 0.0019303054
# Survived [19] steps
# Total reward [7.935094475746155]
# Survived [21] steps
# Total reward [6.8200905323028564]
# Survived [4] steps
# Total reward [2.2592549324035645]
# Survived [11] steps
# Total reward [4.514149963855743]
# loss = 0.0018940686
# Survived [17] steps
# Total reward [7.636426091194153]
# Survived [13] steps
# Total reward [5.54651403427124]
# Survived [16] steps
# Total reward [5.954027712345123]
# Survived [10] steps
# Total reward [3.7195971608161926]
# loss = 0.0031888327
# Survived [9] steps
# Total reward [4.16649067401886]
# Survived [18] steps
# Total reward [8.47348952293396]
# Survived [10] steps
# Total reward [3.7773720622062683]
# Step [149000] -- Random [0.001]
# Successfully saved model at: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large149000.h5
# loss = 0.0041570733
# Survived [16] steps
# Total reward [5.885475516319275]
# Survived [13] steps
# Total reward [4.73376202583313]
# Survived [10] steps
# Total reward [3.8058753609657288]
# Survived [8] steps
# Total reward [3.622957468032837]
# Survived [11] steps
# Total reward [3.918508768081665]
# Survived [8] steps
# Total reward [3.5358908772468567]
# loss = 0.00082707236
# Survived [11] steps
# Total reward [3.980519115924835]
# Survived [16] steps
# Total reward [5.92086398601532]
# Survived [18] steps
# Total reward [6.195205390453339]
# loss = 0.00030440337
# Survived [18] steps
# Total reward [6.341544508934021]
# Survived [8] steps
# Total reward [3.5437577962875366]
# Survived [34] steps
# Total reward [10.72164911031723]
# loss = 0.0029651588
# Survived [15] steps
# Total reward [5.165264189243317]
# Survived [16] steps
# Total reward [5.635234892368317]
# Survived [9] steps
# Total reward [4.02075320482254]
# loss = 0.001709156
# Survived [18] steps
# Total reward [6.394947350025177]
# Survived [8] steps
# Total reward [3.559706449508667]
# Survived [10] steps
# Total reward [3.810052752494812]
# Survived [10] steps
# Total reward [3.9368746876716614]
# Survived [15] steps
# Total reward [7.338188171386719]
# loss = 0.0017637392
# Survived [10] steps
# Total reward [3.747016668319702]
# Survived [12] steps
# Total reward [4.839257001876831]
# Survived [8] steps
# Total reward [4.250310897827148]
# Survived [19] steps
# Total reward [7.733866453170776]
# loss = 0.0010788916
# Survived [17] steps
# Total reward [13.552002668380737]
# Survived [12] steps
# Total reward [9.361664891242981]
# Survived [11] steps
# Total reward [8.471246480941772]
# Survived [3] steps
# Total reward [1.5738755464553833]
# Survived [3] steps
# Total reward [1.59754478931427]
# Survived [10] steps
# Total reward [7.443822383880615]
# loss = 0.0038832147
# Survived [3] steps
# Total reward [1.5574510097503662]
# Survived [10] steps
# Total reward [7.567232728004456]
# Survived [3] steps
# Total reward [1.5966029167175293]
# Survived [3] steps
# Total reward [1.5340017080307007]
# Survived [3] steps
# Total reward [1.5482934713363647]
# Survived [29] steps
# Total reward [24.013259291648865]
# loss = 0.0013859626
# Survived [21] steps
# Total reward [16.494352102279663]
# Survived [23] steps
# Total reward [18.76396405696869]
# Survived [3] steps
# Total reward [1.5827000141143799]
# loss = 0.0013495864
# Survived [14] steps
# Total reward [11.1101154088974]
# Survived [3] steps
# Total reward [1.5150128602981567]
# Survived [6] steps
# Total reward [4.090516209602356]
# Survived [3] steps
# Total reward [1.5342674255371094]
# Survived [3] steps
# Total reward [1.541797161102295]
# Survived [3] steps
# Total reward [1.617883324623108]
# Survived [21] steps
# Total reward [17.022926688194275]
# loss = 0.0015374087
# Survived [5] steps
# Total reward [3.2451006174087524]
# Survived [3] steps
# Total reward [1.6091113090515137]
# Survived [3] steps
# Total reward [1.5889841318130493]
# Survived [4] steps
# Total reward [2.405956983566284]
# Survived [5] steps
# Total reward [2.510731041431427]
# Survived [3] steps
# Total reward [1.5560468435287476]
# Survived [7] steps
# Total reward [4.091423809528351]
# Survived [5] steps
# Total reward [3.280288577079773]
# loss = 0.00048132092
# Survived [17] steps
# Total reward [11.854993999004364]
# Survived [7] steps
# Total reward [4.307707965373993]
# Survived [8] steps
# Total reward [4.9305499792099]
# Survived [7] steps
# Total reward [5.0016738176345825]
# Survived [14] steps
# Total reward [10.860236644744873]
# Survived [8] steps
# Total reward [5.89428174495697]
# loss = 0.0011951338
# Survived [10] steps
# Total reward [5.817095160484314]
# Survived [5] steps
# Total reward [3.3382699489593506]
# Survived [8] steps
# Total reward [4.19474983215332]
# Survived [5] steps
# Total reward [3.2121245861053467]
# Survived [6] steps
# Total reward [4.1487308740615845]
# Survived [8] steps
# Total reward [4.391083776950836]
# Survived [11] steps
# Total reward [5.440715968608856]
# loss = 0.002582307
# loss = 0.002753485
# Survived [87] steps
# Total reward [20.114107370376587]
# loss = 0.0012401778
# loss = 0.0009305267
# Survived [94] steps
# Total reward [19.606088280677795]
# Survived [13] steps
# Total reward [4.020966649055481]
# loss = 0.0007565762
# Step [150000] -- Random [0.001]
# Successfully saved model at: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large150000.h5
# loss = 0.0011610638
# Survived [92] steps
# Total reward [25.350775599479675]
# Survived [29] steps
# Total reward [19.743376910686493]
# loss = 0.0007764775
# Survived [30] steps
# Total reward [12.106346607208252]
# Successfully saved model at: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large150128.h5
# Number of opponent action that are not do_nothing :  508

# %%
steps = list(range(1000, 150001, 1000))
paths = []
for step in steps:
    path = r"saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large{}.h5".format(step)
    paths.append(path)
#     print(path)

# %%
nb_scenario = 5
scores = []
my_score = ScoreL2RPN2020(env_train,
                          nb_scenario=nb_scenario,
                          env_seeds=[0 for _ in range(nb_scenario)],
                          agent_seeds=[0 for _ in range(nb_scenario)])
    
for path in paths:
    agent = D3QNAgent(env_train.observation_space,
                      env_train.action_space,
                      name="DDQN_baseline_nn_concat_large",
                      is_training=False)
    agent.load(path)
    scores.append(my_score.get(agent))
#     print(scores)
# Out:
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large1000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large2000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large3000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large4000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large5000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large6000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large7000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large8000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large9000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large10000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large11000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large12000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large13000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large14000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large15000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large16000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large17000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large18000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large19000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large20000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large21000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large22000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large23000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large24000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large25000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large26000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large27000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large28000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large29000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large30000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large31000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large32000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large33000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large34000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large35000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large36000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large37000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large38000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large39000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large40000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large41000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large42000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large43000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large44000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large45000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large46000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large47000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large48000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large49000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large50000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large51000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large52000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large53000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large54000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large55000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large56000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large57000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large58000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large59000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large60000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large61000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large62000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large63000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large64000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large65000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large66000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large67000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large68000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large69000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large70000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large71000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large72000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large73000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large74000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large75000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large76000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large77000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large78000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large79000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large80000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large81000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large82000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large83000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large84000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large85000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large86000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large87000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large88000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large89000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large90000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large91000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large92000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large93000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large94000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large95000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large96000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large97000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large98000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large99000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large100000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large101000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large102000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large103000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large104000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large105000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large106000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large107000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large108000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large109000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large110000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large111000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large112000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large113000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large114000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large115000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large116000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large117000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large118000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large119000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large120000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large121000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large122000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large123000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large124000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large125000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large126000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large127000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large128000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large129000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large130000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large131000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large132000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large133000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large134000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large135000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large136000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large137000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large138000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large139000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large140000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large141000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large142000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large143000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large144000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large145000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large146000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large147000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large148000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large149000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large150000.h5

# %%
with open('D3QN_baseline_nn_concat_large_train_scores.data', 'wb') as file:
    pickle.dump(scores, file)

# %% [markdown]
# # Validation

# %%
env_val = grid2op.make('l2rpn_neurips_2020_track1_large_val',
                       action_class=TopologyChangeAndDispatchAction, 
                       reward_class=CombinedScaledReward)

# %%
steps = list(range(1000, 150001, 1000))
paths = []
for step in steps:
    path = r"saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large{}.h5".format(step)
    paths.append(path)
#     print(path)

# %%
nb_scenario = 5
scores = []
my_score = ScoreL2RPN2020(env_val,
                          nb_scenario=nb_scenario,
                          env_seeds=[0 for _ in range(nb_scenario)],
                          agent_seeds=[0 for _ in range(nb_scenario)])
    
for path in paths:
    agent = D3QNAgent(env_val.observation_space,
                      env_val.action_space,
                      name="DDQN_baseline_nn_concat_large",
                      is_training=False)
    agent.load(path)
    scores.append(my_score.get(agent))
#     print(scores)
# Out:
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large1000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large2000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large3000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large4000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large5000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large6000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large7000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large8000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large9000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large10000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large11000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large12000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large13000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large14000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large15000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large16000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large17000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large18000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large19000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large20000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large21000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large22000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large23000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large24000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large25000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large26000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large27000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large28000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large29000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large30000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large31000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large32000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large33000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large34000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large35000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large36000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large37000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large38000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large39000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large40000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large41000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large42000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large43000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large44000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large45000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large46000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large47000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large48000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large49000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large50000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large51000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large52000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large53000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large54000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large55000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large56000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large57000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large58000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large59000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large60000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large61000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large62000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large63000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large64000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large65000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large66000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large67000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large68000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large69000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large70000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large71000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large72000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large73000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large74000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large75000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large76000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large77000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large78000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large79000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large80000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large81000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large82000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large83000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large84000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large85000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large86000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large87000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large88000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large89000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large90000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large91000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large92000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large93000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large94000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large95000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large96000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large97000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large98000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large99000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large100000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large101000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large102000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large103000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large104000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large105000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large106000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large107000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large108000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large109000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large110000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large111000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large112000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large113000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large114000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large115000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large116000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large117000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large118000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large119000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large120000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large121000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large122000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large123000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large124000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large125000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large126000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large127000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large128000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large129000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large130000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large131000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large132000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large133000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large134000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large135000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large136000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large137000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large138000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large139000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large140000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large141000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large142000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large143000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large144000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large145000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large146000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large147000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large148000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large149000.h5
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large150000.h5

# %%
with open('D3QN_baseline_nn_concat_large_scores.data', 'wb') as file:
    pickle.dump(scores, file)

# %%
scores_only = [score[0] for score in scores]
val_scores_avg = np.mean(scores_only, axis =1)
best_agent = np.argmax(val_scores_avg)
print("the best agent index: {}".format(best_agent))
# Out:
# the best agent index: 31

# %% [markdown]
# # Test

# %%
env_test = grid2op.make('l2rpn_neurips_2020_track1_large_test',
                        action_class=TopologyChangeAndDispatchAction,
                        reward_class=CombinedScaledReward)

# Only load 128 steps in ram
env_test.chronics_handler.set_chunk_size(128)

# %%
nb_scenario = 10
path = r"saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large32000.h5"

agent = D3QNAgent(env_test.observation_space,
                  env_test.action_space,
                  name="DDQN_baseline_nn_concat_large",
                  is_training=False)
agent.load(path)

for seed in range(3):
    path_save = "saved_agent_DDQN_baseline_nn_concat_large_150000_results{}".format(seed)
    my_score = ScoreL2RPN2020(env_test,
                              nb_scenario=nb_scenario,
                              env_seeds=[seed for _ in range(nb_scenario)],
                              agent_seeds=[seed for _ in range(nb_scenario)])


    test_scores = my_score.get(agent, path_save=path_save)
# Out:
# Successfully loaded network from: saved_agent_DDQN_baseline_nn_concat_large_150000\DDQN_baseline_nn_concat_large32000.h5

# %%
test_scores_only = [score[0] for score in test_scores]

# %%
mean_test_scenarios_score = np.mean(test_scores_only, axis=0)
std_test_scenarios_score = np.std(test_scores_only, axis= 0)
mean_test_score = np.mean(mean_test_scenarios_score)
std_mean_test_score = np.std(mean_test_scenarios_score)

# %%
print("Test score over 10 scenarios (average over 3 runs): {} +\- {}".format(mean_test_scenarios_score, std_test_scenarios_score))
print("Mean test score: {} +\- {}".format(mean_test_score, std_mean_test_score))
# Out:
# Test score over 10 scenarios (average over 3 runs): [ -3.61942388 -11.76359006  -3.70876878 -12.56719439 -20.50018923
#  -20.14791525 -10.07226773  -3.58303591 -13.6406388  -20.1997908 ] +\- [11.24435435 22.85415511 11.34466206 23.80067061 29.04059216 28.53026248
#  20.40921008 11.2120474  25.50738305 28.59452083]
# Mean test score: -11.980281482991211 +\- 6.499874790869417

# %% [markdown]
# # Analysis

# %%
from grid2op.Episode import EpisodeData
from grid2op.Episode import EpisodeReplay

# %%
env_test = grid2op.make('l2rpn_neurips_2020_track1_large_test',
                        action_class=TopologyChangeAndDispatchAction,
                        reward_class=CombinedScaledReward)

# Only load 128 steps in ram
env_test.chronics_handler.set_chunk_size(128)

# %%
path_save = 'saved_agent_DDQN_baseline_nn_concat_large_150000_results1'

# %%
episode_studied = "Scenario_april_062"
this_episode = EpisodeData.from_disk(path_save, episode_studied)

# %%
attacks =[]
timesteps = []
step = 0

for attack in this_episode.attacks:
    if attack != env_test.action_space():
        if attack not in attacks:
            attacks.append(attack)
            timesteps.append(step)
            print(attack)
            print(step)
    step += 1
# Out:
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - Force disconnection of 1 powerlines ([27])
# 	 - NOT switch any line status
# 	 - NOT switch anything in the topology
# 	 - NOT force any particular bus configuration
# 277
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - Force disconnection of 1 powerlines ([56])
# 	 - NOT switch any line status
# 	 - NOT switch anything in the topology
# 	 - NOT force any particular bus configuration
# 328

# %%
step = 0
actions =[]
act_timesteps = []

for action in this_episode.actions:
    if action != env_test.action_space():
        if action not in actions:
            actions.append(action)
            timesteps.append(step)
            print(action)
            print(step)
    step += 1
# Out:
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - Change the bus of the following element(s):
# 	 	 - Switch bus of line (origin) id 34 [on substation 23]
# 	 	 - Switch bus of line (origin) id 38 [on substation 23]
# 	 - NOT force any particular bus configuration
# 3
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - Change the bus of the following element(s):
# 	 	 - Switch bus of line (origin) id 34 [on substation 23]
# 	 	 - Switch bus of generator id 13 [on substation 23]
# 	 - NOT force any particular bus configuration
# 13
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - Change the bus of the following element(s):
# 	 	 - Switch bus of line (extremity) id 19 [on substation 16]
# 	 	 - Switch bus of generator id 5 [on substation 16]
# 	 - NOT force any particular bus configuration
# 329
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - Change the bus of the following element(s):
# 	 	 - Switch bus of line (extremity) id 19 [on substation 16]
# 	 	 - Switch bus of load id 17 [on substation 16]
# 	 - NOT force any particular bus configuration
# 330

# %%
last_obs = copy.deepcopy(this_episode.observations[-1])

plot_helper1 = PlotMatplot(observation_space=this_episode.observation_space)
fig = plot_helper1.plot_obs(last_obs)
fig.savefig("last obs nn 062")
fig.show()
# Out:
# <ipython-input-70-49b4aeaa4afd>:6: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
path_save = 'saved_agent_DDQN_baseline_nn_concat_large_150000_results1'

# %%
episode_studied = "Scenario_april_170"
this_episode = EpisodeData.from_disk(path_save, episode_studied)

# %%
attacks =[]
timesteps = []
step = 0

for attack in this_episode.attacks:
    if attack != env_test.action_space():
        if attack not in attacks:
            attacks.append(attack)
            timesteps.append(step)
            print(attack)
            print(step)
    step += 1
# Out:
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - Force disconnection of 1 powerlines ([27])
# 	 - NOT switch any line status
# 	 - NOT switch anything in the topology
# 	 - NOT force any particular bus configuration
# 277
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - Force disconnection of 1 powerlines ([56])
# 	 - NOT switch any line status
# 	 - NOT switch anything in the topology
# 	 - NOT force any particular bus configuration
# 328

# %%
step = 0
actions =[]
act_timesteps = []

for action in this_episode.actions:
    if action != env_test.action_space():
        if action not in actions:
            actions.append(action)
            timesteps.append(step)
            print(action)
            print(step)
    step += 1
# Out:
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - Change the bus of the following element(s):
# 	 	 - Switch bus of line (origin) id 34 [on substation 23]
# 	 	 - Switch bus of line (origin) id 38 [on substation 23]
# 	 - NOT force any particular bus configuration
# 3
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - Change the bus of the following element(s):
# 	 	 - Switch bus of line (origin) id 34 [on substation 23]
# 	 	 - Switch bus of generator id 13 [on substation 23]
# 	 - NOT force any particular bus configuration
# 13
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - Change the bus of the following element(s):
# 	 	 - Switch bus of line (extremity) id 19 [on substation 16]
# 	 	 - Switch bus of load id 17 [on substation 16]
# 	 - NOT force any particular bus configuration
# 329

# %%
plt.figure()
plt.plot(baseline_acts, label='D3QN-baseline')
plt.plot(input_acts, label='D3QN-input-concat')
plt.plot(nn_acts, label='D3QN-nn-concat')
plt.axvspan(276, 324, alpha=0.2, color='red', label='attack')
plt.axvspan(328, 335, alpha=0.2, color='red')
plt.legend()
plt.xlabel('Timestep')
plt.ylabel('Cumulative Number of Actions')
plt.savefig('Scenario_actions')
plt.tight_layout()

plt.show()

# %%
plt.figure()
plt.plot(baseline_acts, label='D3QN-baseline')
plt.plot(input_acts, label='D3QN-input-concat')
plt.plot(nn_acts, label='D3QN-nn-concat')
plt.axvspan(276, 324, alpha=0.2, color='red', label='attack')
plt.axvspan(328, 335, alpha=0.2, color='red')
plt.legend()
plt.xlabel('Timestep')
plt.ylabel('Cumulative Number of Actions')
plt.savefig('Scenario_actions2')
plt.tight_layout()

plt.show()

# %%
last_obs = copy.deepcopy(this_episode.observations[-1])

plot_helper1 = PlotMatplot(observation_space=this_episode.observation_space)
fig = plot_helper1.plot_obs(last_obs)
fig.savefig("last obs nn 170")
fig.show()
# Out:
# <ipython-input-74-50a231153aa3>:6: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
